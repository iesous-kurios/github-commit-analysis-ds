# %%
import pandas as pd
import numpy as np
import json

# %%
# %pwd
# Out:
# 'C:\\Users\\jwyli\\Downloads'

# %%
data = pd.read_json('My_Request-1589942477185.json')

# %%
data.sample(5)
# Out:
#                                                   url  \
# 4   https://api.github.com/repos/kubernetes/kubern...
# 2   https://api.github.com/repos/kubernetes/kubern...
# 10  https://api.github.com/repos/kubernetes/kubern...
# 29  https://api.github.com/repos/kubernetes/kubern...
# 8   https://api.github.com/repos/kubernetes/kubern...
#
#                                        repository_url  \
# 4   https://api.github.com/repos/kubernetes/kubern...
# 2   https://api.github.com/repos/kubernetes/kubern...
# 10  https://api.github.com/repos/kubernetes/kubern...
# 29  https://api.github.com/repos/kubernetes/kubern...
# 8   https://api.github.com/repos/kubernetes/kubern...
#
#                                            labels_url  \
# 4   https://api.github.com/repos/kubernetes/kubern...
# 2   https://api.github.com/repos/kubernetes/kubern...
# 10  https://api.github.com/repos/kubernetes/kubern...
# 29  https://api.github.com/repos/kubernetes/kubern...
# ...

# %%
test.shape
# Out:
# (30, 24)

# %%
test['comments'].value_counts()
# Out:
# 3     7
# 4     5
# 2     5
# 5     4
# 8     2
# 6     2
# 16    1
# 14    1
# 7     1
# 1     1
# 0     1
# Name: comments, dtype: int64
